# %% [markdown]
# [![Open in Google Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/danielmlow/construct-tracker/blob/daniels_branch/tutorials/construct_tracker.ipynb)
#
# # Tutorial to use construct-tracker to measure the constructs you choose in text:
#
# - Author: Daniel M. Low
# - License: Apache 2.0
# - Date: 29/07/2024
# - **If you use, please cite**: Low DM, Rankin O, Coppersmith DDL, Bentley KH, Nock MK, Ghosh SS (2024). Building lexicons with Generative AI result in zero-shot, lightweight, interpretable text models with high content validity. arXiv.

# %% [markdown]
# ### construct-tracker
# ##### - **zero-shot**: no training data needed. Just provide the list of constructs and some examples.
# ##### - **lightweight**: no GPU needed
# ##### - **private and free**: you can run on your local computer instead of submitting to a cloud API
# ##### - **interpretable**: understand why the model outputs a given score
# ##### - **content validity**: measure what you actually want to measure
#
#
# There are three options:
# * **Lexicon**: Create a lexicon with Generative AI for the constructs you want to measure and obtain the counts of those constructs in text.
# * **Lexicon + construct-text similarity (CTS)**: find similar meaning phrases: Since counting exact matches will miss similar and relevant words, use CTS to include similar phrases. **recommended**
# * **Just construct-text similarity (CTS)**: skip creating a lexicon and just provide CTS with a few examples (might not work as well). No API key needed.
#
#
# We provide A) "Quick start" section below followed by a B) "Use all special features" section

# %%
# Install construct-tracker 

# development mode:
# !pip install git+https://github.com/danielmlow/construct-tracker.git@daniels_branch#egg=construct_tracker&subdirectory=dist

# production mode:
# pip install contruct-tracker

# # Local mode
# import sys
# sys.path.append('./../src/')
# sys.path.append('./../src/construct_tracker/')

# %%
# Import packages
import pandas as pd
import sys
import os
import shutil 
import datetime
import copy
from construct_tracker import lexicon
from construct_tracker import cts

# %% [markdown]
# Let's create a lexicon to measure constructs related to insight and mindfulness. Here are some examples from a target dataset of documents (e.g., survey responses, social media posts).

# %%
documents = [
 'Every time I speak with my cousin Bob, I have great moments of insight, clarity, and wisdom',
 "He meditates a lot, but he's not super smart",
 'He is too competitive']

# %%
# Or load from Google Drive 
google_drive = False # Load files from Google Drive

if google_drive:
	current_path = '/content/drive/My Drive/Colab Notebooks'
	# Sign into drive to gain access to your documents in a dataframe and/or api_keys.py
	from google.colab import drive
	drive.mount('/content/drive')
	sys.path.append(current_path)
	# Change path and column name accordingly.
	documents = pd.read_csv('/content/drive/My Drive/insight_project/my_documents.csv')['documents_column'].tolist()

# %%
if google_drive:
	# Sign into drive to gain access to your documents in a dataframe and/or api_keys.py
	
	
	lexicon_dir = current_path+'/ct_lexicons/' #to save from the lexicon
	output_dir = current_path+'/ct_datasets/' # to save final datasets
	# CHANGE PATH
	documents = pd.read_csv('/content/drive/My Drive/your_project_name/your_csv_file.csv')['documents_column_name'].tolist()
else:

	lexicon_dir = './ct_lexicons/' #to save from the lexicon
	output_dir = './ct_datasets/' # to save final datasets

os.makedirs(lexicon_dir, exist_ok=True)
os.makedirs(output_dir, exist_ok=True)

# %% [markdown]
# # Create lexicon with generative AI
#
# If you want to use generative AI models from python, you need to provide a key from a given provider (e.g., OpenAI, Google, etc.). Alternatively, you can use chatgpt, bing or other browsers, to obtain a list and then copy and paste when indicated below.

# %% [markdown]
# # Add API keys
#
# Each provider has one API key associated to your account. Choose provider and a specific provider's model: https://docs.litellm.ai/docs/providers
#
# **Free trial key**
# - Some providers offer a key for a few submissions per minute for free.
# - Obtain Cohere key:
# 	1. Sign in to https://dashboard.cohere.com/api-keys
# 	2. copy the key under "Trial keys FREE"
#
#
# **Paid key**
# - Obtain OpenAI key:
# 	1. Select "Log in" (upper right corner): https://platform.openai.com/
# 	2. Select "Dashboard" (upper right corner)
# 	3. Select "API keys" (left panel)
# 	4. Select "Create new secret key"

# %% [markdown]
# Add your private API key
#
# - **Option A** As a string here for the models you wish to use. Just be careful to not share this ipynb with your private key.

# %%
os.environ["OPENAI_API_KEY"]  = "YOUR_OPENAI_API_KEY"

# %% [markdown]
# - **Option B** load api_keys.py locally or from google drive, where you save all your private API keys.

# %%
google_drive = False # Load files from / save to Google Drive

if google_drive:
	# Sign into drive to gain access to your documents in a dataframe and/or api_keys.py
	from google.colab import drive
	drive.mount('/content/drive')
	sys.path.append('/content/drive/My Drive/Colab Notebooks')

	# Now you can load documents from Google Drive and/or api_keys.py, change path and column name accordingly.
	
	# See explanation and instructions in Quick Start above. 
	

try:
	import api_keys # local api_keys.py file (where there are variables open_ai='MY-API-KEY') or add string below.
	os.environ["OPENAI_API_KEY"]  = api_keys.open_ai  # private API key, add string here or load from other file for privacy
except:
	print('could not import api_keys.py file. Please add string below or load from other file for privacy. ')
	pass

# %% [markdown]
# Now specify which model to use

# %%
gpt4o = "gpt-4o-2024-05-13" # model name
gpt4o_mini = "gpt-4o-mini-2024-07-18"

# Select a model you'll use for now:
model = gpt4o_mini

# %% [markdown]
# # A. Quick start

# %% [markdown]
# ### 1. Build lexicon with Generative AI and then count in documents

# %%
my_lexicon = lexicon.Lexicon()         # Initialize lexicon

my_lexicon.add('Insight', section = 'tokens', value = 'create', source = model, max_tokens = 150,
	  examples = ['insight', 'realized'])

my_lexicon.add('Mindfulness', section = 'tokens', value = 'create', source = model, max_tokens = 150,
	examples = ['mindfulness', 'meditate'])

my_lexicon.add('Compassion', section = 'tokens', value = 'create', source = model, max_tokens = 150,
	examples = ['compassion', 'love', 'kind', 'help others'])
# Out:
# INFO: Adding 'Insight' to the lexicon (it was not previously there). If you meant to add to an existing construct (and have a typo in the construct name, which is case sensitive), run: del your_lexicon_name.constructs['Insight']
# INFO: Adding 'Mindfulness' to the lexicon (it was not previously there). If you meant to add to an existing construct (and have a typo in the construct name, which is case sensitive), run: del your_lexicon_name.constructs['Mindfulness']
# INFO: Adding 'Compassion' to the lexicon (it was not previously there). If you meant to add to an existing construct (and have a typo in the construct name, which is case sensitive), run: del your_lexicon_name.constructs['Compassion']

# %% [markdown]
# 1.1. View lexicons

# %%
print(my_lexicon.constructs['Insight']['tokens'])

print(my_lexicon.constructs['Mindfulness']['tokens'])

print(my_lexicon.constructs['Compassion']['tokens'])
# Out:
# ['acumen', 'analysis', 'analytical thinking', 'astuteness', 'awareness', 'breakthrough', 'clarity', 'clarity of thought', 'clear perception', 'cognitive insight', 'comprehension', 'conceptual clarity', 'critical thinking', 'deep understanding', 'discerning observation', 'discernment', 'discovery', 'enlightened perspective', 'enlightenment', 'epiphany', 'foresight', 'grasp', 'informed decision', 'insight', 'insight-driven', 'insightful analysis', 'insightful revelation', 'insightfulness', 'interpretation', 'intuition', 'intuitive understanding', 'keen perception', 'knowledge', 'mental clarity', 'observation', 'perception', 'perceptive observation', 'perceptual awareness', 'perspective', 'profound insight', 'profound realization', 'realized', 'recognition', 'reflection', 'reflective thought', 'revelation', 'situational awareness', 'strategic insight', 'thoughtful analysis', 'thoughtful insight', 'understanding', 'wisdom']
# ['acceptance', 'awareness', 'awareness practice', 'balance', 'body scan', 'breathing', 'breathwork', 'calm', 'centering', 'clarity', 'compassion', 'compassion practice', 'connection', 'deep listening', 'detachment', 'emotional regulation', 'equanimity', 'flow', 'focus', 'gratitude', 'grounding', 'harmony', 'inner peace', 'insight', 'intention', 'intention setting', 'joy', 'loving-kindness', 'meditate', 'mindful eating', 'mindful movement', 'mindful walking', 'mindfulness', 'moment', 'nature', 'non-judgment', 'non-reactivity', 'observation', 'patience', 'presence', 'present moment', 'reflection', 'release', 'resilience', 'self-awareness', 'self-care', 'self-compassion', 'self-reflection', 'sensory awareness', 'silence', 'simplicity', 'still', 'stillness', 'stress reduction', 'surrender', 'tranquility', 'visualization']
# ['acceptance', 'advocate', 'altruism', 'benevolence', 'caring', 'charity', 'comfort', 'compassion', 'compassion and action', 'compassion fatigue', 'compassion for others', 'compassion for self', 'compassion in', 'compassion in action', 'compassion in community', 'compassion in education', 'compassion in leadership', 'compassion in relationships', 'compassion journey', 'compassion mindset', 'compassion practice', 'compassion towards animals', 'compassion towards nature', 'compassionately', 'concern', 'connection', 'embrace', 'empathy', 'encouragement', 'forgiveness', 'generosity', 'goodwill', 'grace', 'healing', 'heart', 'help others', 'humanity', 'kind', 'kindness', 'listen', 'love', 'mindfulness', 'nurture', 'outreach', 'patience', 'presence', 'respect', 'selflessness', 'service', 'share', 'solace', 'support', 'sympathy', 'tenderness', 'togetherness', 'understanding', 'uplift', 'volunteer', 'warmth']

# %% [markdown]
# 1.2. Now count whether tokens appear in document:

# %%
counts, matches_by_construct, matches_doc2construct, matches_construct2doc  = my_lexicon.extract(documents,
                                                                                      normalize = False,
                                                                                      )

counts.to_csv(f'{output_dir}insight_lexicon_counts.csv', index = False)
display(counts)
# Out:
# extracting...
#   0%|          | 0/3 [00:00<?, ?it/s]WARNING: Lemmatizing the tokens. We recommend you lemmatize before extracting so you can save time if you want to repeat extraction on different documents.
#  33%|███▎      | 1/3 [00:04<00:09,  4.90s/it]WARNING: Lemmatizing the tokens. We recommend you lemmatize before extracting so you can save time if you want to repeat extraction on different documents.
#  67%|██████▋   | 2/3 [00:05<00:02,  2.48s/it]WARNING: Lemmatizing the tokens. We recommend you lemmatize before extracting so you can save time if you want to repeat extraction on different documents.
# 100%|██████████| 3/3 [00:06<00:00,  2.05s/it]
#    document_id                                           document  Insight  \
# 0            0  Every time I speak with my cousin Bob, I have ...        3
# 1            1       He meditates a lot, but he's not super smart        0
# 2            2                              He is too competitive        0
#
#    Mindfulness  Compassion  word_count
# 0            3           0          17
# 1            1           0           8
# 2            0           0           4

# %% [markdown]
# 1.3. Interpret counts: visualize matches in context

# %%
show_n_sentences = 2
construct = 'Mindfulness'
print(f'Matches for {construct}:')
lexicon.highlight_matches(documents, construct,show_n_sentences, matches_construct2doc)
print()


construct = 'Insight'
print(f'Matches for {construct}:')
lexicon.highlight_matches(documents, construct,show_n_sentences, matches_construct2doc)
print()
# Out:
# Matches for Mindfulness:
# He <mark>meditate</mark>s a lot, but he's not super smart
# Every time I speak with my cousin Bob, I have great <mark>moment</mark>s of <mark>insight</mark>, <mark>clarity</mark>, and wisdom
# Matches for Insight:
# Every time I speak with my cousin Bob, I have great moments of <mark>insight</mark>, <mark>clarity</mark>, and <mark>wisdom</mark>

# %% [markdown]
# ### 2. Construct-Text Similarity (CTS)
#
# 2.1. Similarity between lexicon tokens and document tokens

# %%
lexicon_dict = my_lexicon.to_dict()
features, documents_tokenized, lexicon_dict_final_order, cosine_similarities = cts.measure(
    lexicon_dict,
    documents,
	count_if_exact_match = False, # False: for now, do not add exact matches to similarities nor replace similarities for exact matches when found. However, we recommend using 'sum', which sums these similarities to any counts of exact matches. See full example below.
	verbose = True # True: Log information for each step 
    )

display(features.round(2))

features.to_csv(f'{output_dir}insight_lexicon_cts_features.csv', index = False)
# Out:
# WARNING: stored_embeddings_path is None. Extracting all lexicon token embeddings from scratch instead of loading stored embeddings...
# INFO: Default input sequence length for all-MiniLM-L6-v2: 256
# INFO: Encoding 336 new construct tokens...
# Batches:   0%|          | 0/11 [00:00<?, ?it/s]
# INFO: Finished encoding construct tokens.
# INFO: Tokenizing documents...
# INFO: Finished tokenization.
# INFO: Encoding all document tokens...
# INFO: computing similarity between 3 constructs and 3 documents...
# 3it [00:00, 322.61it/s]
# INFO: Finished.
#    document_id                                          documents  \
# 0            0  Every time I speak with my cousin Bob, I have ...
# 1            1       He meditates a lot, but he's not super smart
# 2            2                              He is too competitive
#
#                                  documents_tokenized  Insight_max  \
# 0  [Every time I speak with my cousin Bob, I have...         0.48
# 1         [He meditates a lot, he's not super smart]         0.34
# 2                            [He is too competitive]         0.00
#
#    Mindfulness_max  Compassion_max
# 0             0.38            0.30
# 1             0.72            0.48
# 2             0.00            0.00

# %% [markdown]
# #### Interpret: see why a certain document received a score for a given construct

# %%
doc_id = 1
construct = 'Mindfulness'
most_similar_lexicon_token, most_similar_document_token, highest_similarity = cts.get_highest_similarity_phrase(doc_id, construct, documents, documents_tokenized, cosine_similarities, lexicon_dict_final_order)
# Out:
# The construct 'Mindfulness' through its token 'meditate' had the highest cosine similarity (0.72) with the following document token:
# 'He meditates a lot'
# <mark>He meditates a lot</mark>, but he's not super smart

# %% [markdown]
# # B. Use all special features
#
# Recommended: download and run this on your local computer using jupyter lab, vscode, or your favorite development environment. Saving to and from files is quicker if run locally on your computer than on Google Drive.

# %% [markdown]
# ### 1. Build lexicon with Generative AI
#
#
# #### Lexicon step 1.1: First provide api keys and general info on the lexicon

# %%
my_lexicon = lexicon.Lexicon()			# Initialize lexicon
my_lexicon.name = 'Insight'		# Set lexicon name
my_lexicon.description = 'Insight lexicon with constructs inspired by items of the Emotional Insight Scale'
my_lexicon.creator = 'DML' 				# your name or initials for transparency in logging who made changes
my_lexicon.version = '1.0'				# Set version. Over time, others may modify your lexicon, so good to keep track. MAJOR.MINOR. (e.g., MAJOR: new constructs or big changes to a construct, Minor: small changes to a construct)

# %%
# Fill out this information
domain = 'psychology' # Optional: bias definitions to a certain domain. this can be "mental health", "economics" or set to None (no quotation marks)
models_for_lexicon = [gpt4o] # Here you could add more: [gpt4o,command_nightly]
model_for_definition = gpt4o # You can ask model to create definition for each construct in the lexicon. Or set to None (no quotation marks)
temperatures = [0,0.5,1] # Temperature is another important parameter that defines how creative a model should be (0: a model outputs the most probable tokens given the prompt and training data; 1=more creative and less predictable responses, with a maximum of 2, which is not often used).

# %% [markdown]
# #### Lexicon step 1.2: Add examples and definitions manually or using a model
#
# **Examples**
#
# Add a few prototypical tokens you don't want to miss. With these examples, help guide the model as to whether you want adjectives, nouns, phrases or all of the above.
#
#
# **Definitions**
#
# We recommend this for expert validation (step after creating the lexicon, so raters can decide whether to include a token as a function of a specific definition). However, you can decide whether the Generative AI model sees the definition or not so as to guide or not guide the lexicon creation.
#
# We'll show an example where we manually provided a definition (insight), where we'll have our model provide it, and where we will not include it.

# %%
# Fill in

construct_information = {
	'Insight': {
		'examples': ['clarity', 'enlightenment', 'wise'],
		'definition': "the clarity of understanding of one's thoughts, feelings and behavior",
		'reference': "Grant, A. M., Franklin, J., & Langford, P. (2002). The self-reflection and insight scale: A new measure of private self-consciousness. Social Behavior and Personality: an international journal, 30(8), 821-835."
			 },
	'Mindfulness': {
		'examples': ['mindful','meditation', 'awareness', 'nonjudgemental', 'present-focused'],
		'definition': model_for_definition, # it will later check if definition == model_for_definition, if it does, it will generate using that model
		'reference':model_for_definition
			 },	
	'Compassion': {
		'examples':['compassion', 'love', 'kind', 'help others'],
		'definition': None,
		'reference':None
			 },
}

## Definition will be added if model_for_definition is not None using our own prompt. Or you can can directly prompt APIs here with your own prompt. This is our default one:
# prompt = f"Provide a brief definition of {construct} (in the {domain} domain). Provide reference in APA format where you got it from. Return result in the following format: {'{construct}': 'the_definition', 'reference':'the_reference'}"
# definition = api_request(prompt, model = model)

# %%
my_lexicon.add('Insight', section = 'tokens', value = 'create', source = model, max_tokens = 150,
	  examples = ['insight', 'realized'])

my_lexicon.add('Mindfulness', section = 'tokens', value = 'create', source = model, max_tokens = 150,
	examples = ['mindfulness', 'meditate'])

my_lexicon.add('Compassion', section = 'tokens', value = 'create', source = model, max_tokens = 150,
	examples = ['compassion', 'love', 'kind', 'help others'])
# Out:
# INFO: Adding 'Insight' to the lexicon (it was not previously there). If you meant to add to an existing construct (and have a typo in the construct name, which is case sensitive), run: del your_lexicon_name.constructs['Insight']
# INFO: Adding 'Mindfulness' to the lexicon (it was not previously there). If you meant to add to an existing construct (and have a typo in the construct name, which is case sensitive), run: del your_lexicon_name.constructs['Mindfulness']
# INFO: Adding 'Compassion' to the lexicon (it was not previously there). If you meant to add to an existing construct (and have a typo in the construct name, which is case sensitive), run: del your_lexicon_name.constructs['Compassion']

# %%
# Loop through constructs and generate lexicon and definition as instructed above in construct_information

for construct, information in construct_information.items():
	print('\n',construct, ' ------------------------')
	examples, definition, reference = information['examples'], information['definition'], information['reference']
	
	# DEFINITION: add definition or use model to get one
	# ===================================================
	construct_dict = construct_information.get(construct)
	# if definition exists (is str), use it.
	if construct_dict['definition'] == model_for_definition:
		# Use model to create a definition
		definition, reference = my_lexicon.generate_definition(construct, model = model_for_definition, domain=domain, timeout=45, num_retries=2)
		print(f'Generated definition: {definition}\n')
		print(f'Reference: {reference}\n')
		# Update with definition
		construct_information[construct] = {'definition': definition, 'reference': reference}
	elif isinstance(construct_dict['definition'], str):
		definition = construct_dict['definition']
		reference = construct_dict['reference']
	elif construct_dict['definition'] == None:
		definition = None
		reference = None

	# PROMPT: add definition and examples to prompt
	# ===================================================
	prompt = lexicon.generate_prompt(construct,
                         prompt_name=construct,
                         domain = domain,
						 definition = definition,
						 examples = examples)
	
	print('Prompt used:')
	print(prompt)
	print()

	## Or create your own prompt here:
	# prompt = """
	# Create a list of words and phrases related to {construct} in the {domain} domain. Here are some examples: {examples}
	# """
	# prompt.format(construct = construct, domain = domain, example = examples)
	# print(prompt)
	
	# Generate lexicon
	# ===================================================
	# Each model and temperature will create redudant and new tokens. They will merge with other tokens already generated. 
	for model in models_for_lexicon:
		for temperature in temperatures:
			my_lexicon.add(construct, section = 'tokens', value = 'create', prompt = prompt, source = model, temperature = temperature, max_tokens = 150,
				# so these are saved to metadata
				domain = domain, examples = examples, definition = definition,definition_references = reference, )
	print('Models used to generate tokens:')
	[print(n) for n in list(my_lexicon.constructs[construct]['tokens_metadata'].keys())]
	print()
	print('Generated lexicon:', my_lexicon.constructs[construct]['tokens']) 
	print()
# Out:
#  Insight  ------------------------
# Prompt used:
# Provide many single words and some short phrases (all in lower case unless the word is generally in upper case) related to Insight (in the psychology domain). Each token should be separated by a semicolon. Do not return duplicate tokens. Do not provide any explanation or additional text beyond the tokens.
# Here is a definition of Insight: the clarity of understanding of one's thoughts, feelings and behavior
# Here are some examples (include these in the list): clarity; enlightenment; wise
#
# Models used to generate tokens:
# gpt-4o-mini-2024-07-18, temperature-0.1, top_p-1, max_tokens-150, seed-42, 24-08-12T19-42-38.357967
# gpt-4o-2024-05-13, temperature-0, top_p-1, max_tokens-150, seed-42, 24-08-12T19-42-44.868840
# gpt-4o-2024-05-13, temperature-0.5, top_p-1, max_tokens-150, seed-42, 24-08-12T19-42-47.102237
# gpt-4o-2024-05-13, temperature-1, top_p-1, max_tokens-150, seed-42, 24-08-12T19-42-49.254632
#
# Generated lexicon: ['acuity', 'acumen', 'aha moment', 'analysis', 'analytical thinking', 'astuteness', 'awareness', 'breakthrough', 'brilliance', 'clarity', 'clear vision', 'cognition', 'cognitive shift', 'comprehension', 'consciousness', 'contemplation', 'critical thinking', 'deduction', 'deep dive', 'deep understanding', 'depth', 'detection', 'discernment', 'discovery', 'enlightened thought', 'enlightenment', 'epiphany', 'foresight', 'fresh perspective', 'grasp', 'grasping', 'holistic view', 'illumination', 'insight', 'insight-driven', 'insightful analysis', 'insightfulness', 'interpretation', 'introspection', 'intuition', 'intuitive grasp', 'judiciousness', 'keen observation', 'keenness', 'knowledge', 'lucidity', 'mental clarity', 'mindfulness', 'new angle', 'observance', 'observant', 'observation', 'paradigm shift', 'perception', 'perceptive', 'perceptive insight', 'perceptiveness', 'perspective', 'perspicacity', 'perspicuity', 'profound understanding', 'profundity', 'prudence', 'realization', 'realized', 'recognition', 'reflection', 'revelation', 'sagacity', 'self-awareness', 'self-knowledge', 'sharp awareness', 'sharpness', 'shrewdness', 'strategic insight', 'synthesis', 'thoughtful consideration', 'thoughtful insight', 'thoughtful reflection', 'understanding', 'wisdom', 'wise']
#
#
#  Mindfulness  ------------------------
# Generated definition: Mindfulness is the psychological process of bringing one's attention to experiences occurring in the present moment, which can be developed through the practice of meditation and other training.
#
# Reference: gpt-4o-2024-05-13 which references: American Psychological Association. (2023). Mindfulness. In APA Dictionary of Psychology. Retrieved from https://dictionary.apa.org/mindfulness
#
# Prompt used:
# Provide many single words and some short phrases (all in lower case unless the word is generally in upper case) related to Mindfulness (in the psychology domain). Each token should be separated by a semicolon. Do not return duplicate tokens. Do not provide any explanation or additional text beyond the tokens.
# Here is a definition of Mindfulness: mindfulness is the psychological process of bringing one's attention to experiences occurring in the present moment, which can be developed through the practice of meditation and other training.
# Here are some examples (include these in the list): mindful; meditation; awareness; nonjudgemental; present-focused
#
# Models used to generate tokens:
# gpt-4o-mini-2024-07-18, temperature-0.1, top_p-1, max_tokens-150, seed-42, 24-08-12T19-42-40.722780
# gpt-4o-2024-05-13, temperature-0, top_p-1, max_tokens-150, seed-42, 24-08-12T19-42-52.978642
# gpt-4o-2024-05-13, temperature-0.5, top_p-1, max_tokens-150, seed-42, 24-08-12T19-42-54.840277
# gpt-4o-2024-05-13, temperature-1, top_p-1, max_tokens-150, seed-42, 24-08-12T19-42-57.982166
#
# Generated lexicon: ['acceptance', 'acceptance practice', 'attention', 'attunement', 'awareness', 'awareness of breath', 'awareness of thoughts', 'awareness practice', 'balance', 'being', 'body scan', 'body-scan', 'breathing', 'calm', 'centeredness', 'centering', 'clarity', 'compassion', 'compassion practice', 'concentration', 'conscious', 'consciousness', 'curiosity', 'deep listening', 'detachment', 'dharma', 'emotional balance', 'emotional regulation', 'emotions', 'empathy', 'equanimity', 'flow', 'focus', 'gentle', 'gratitude', 'grounding', 'harmony', 'here and now', 'inner peace', 'insight', 'intention', 'intentional', 'intentionality', 'introspection', 'joy', 'kindness', 'letting go', 'listening', 'loving-kindness', 'mantra', 'meditate', 'meditation', 'mental clarity', 'metacognition', 'metta', 'mindful', 'mindful breathing', 'mindful eating', 'mindful listening', 'mindful movement', 'mindful walking', 'mindfulness', 'mindfulness-based', 'moment', 'moment to moment', 'nature', 'non-attachment', 'non-judgment', 'non-reactivity', 'nonattachment', 'nonjudgemental', 'nonreactive', 'nonreactivity', 'noticing', 'observance', 'observation', 'open-minded', 'openness', 'patience', 'peace', 'perception', 'poise', 'presence', 'present moment', 'present-focused', 'reflection', 'relaxation', 'resilience', 'self-awareness', 'self-care', 'self-compassion', 'self-inquiry', 'self-regulation', 'sensations', 'serenity', 'silence', 'simplicity', 'stillness', 'stress reduction', 'thoughts', 'tranquility', 'vipassana', 'visualization', 'yoga', 'zen']
#
#
#  Compassion  ------------------------
# Prompt used:
# Provide many single words and some short phrases (all in lower case unless the word is generally in upper case) related to Compassion (in the psychology domain). Each token should be separated by a semicolon. Do not return duplicate tokens. Do not provide any explanation or additional text beyond the tokens.
# Here are some examples (include these in the list): compassion; love; kind; help others
#
# Models used to generate tokens:
# gpt-4o-mini-2024-07-18, temperature-0.1, top_p-1, max_tokens-150, seed-42, 24-08-12T19-42-42.843959
# gpt-4o-2024-05-13, temperature-0, top_p-1, max_tokens-150, seed-42, 24-08-12T19-43-00.583562
# gpt-4o-2024-05-13, temperature-0.5, top_p-1, max_tokens-150, seed-42, 24-08-12T19-43-03.280720
# gpt-4o-2024-05-13, temperature-1, top_p-1, max_tokens-150, seed-42, 24-08-12T19-43-05.823341
#
# Generated lexicon: ['acceptance', 'active listening', 'advocacy', 'affective empathy', 'altruism', 'attunement', 'benevolence', 'care', 'caring actions', 'charity', 'cognitive empathy', 'comfort', 'community', 'compassion', 'compassion fatigue', 'compassion in action', 'compassion meditation', 'compassion practice', 'compassion satisfaction', 'compassion training', 'compassion-driven', 'compassion-focused', 'compassion-focused therapy', 'compassionate communication', 'compassionate leadership', 'compassionately', 'connectedness', 'connection', 'emotional intelligence', 'emotional support', 'empathetic concern', 'empathic concern', 'empathy', 'empathy building', 'empathy fatigue', 'empathy gap', 'empathy training', 'encouragement', 'forgiveness', 'generosity', 'gentleness', 'goodwill', 'grace', 'gratitude', 'healing', 'heartfulness', 'help others', 'humanity', 'humility', 'kind', 'kindness', 'listening', 'love', 'loving-kindness', 'mercy', 'mindfulness', 'moral elevation', 'non-judgment', 'nonjudgmental', 'nurture', 'nurturing', 'outreach', 'outreach programs', 'patience', 'positive regard', 'presence', 'prosocial behavior', 'rapport', 'relational depth', 'resilience', 'respect', 'self-compassion', 'selflessness', 'sensitivity', 'service', 'shared experience', 'social responsibility', 'social support', 'solace', 'solidarity', 'support', 'sympathy', 'tenderness', 'togetherness', 'tolerance', 'trust', 'unconditional positive regard', 'understanding', 'uplift', 'validation', 'volunteerism', 'warmth', 'well-being']

# %% [markdown]
# #### Lexicon step 1.3: Important: review resulting lexicon. Add or remove tokens manually.

# %%
for construct in construct_information.keys():
	print(f"{construct}:", my_lexicon.constructs[construct]['tokens'])
# Out:
# Insight: ['acuity', 'acumen', 'aha moment', 'analysis', 'analytical thinking', 'astuteness', 'awareness', 'breakthrough', 'brilliance', 'clarity', 'clear vision', 'cognition', 'cognitive shift', 'comprehension', 'consciousness', 'contemplation', 'critical thinking', 'deduction', 'deep dive', 'deep understanding', 'depth', 'detection', 'discernment', 'discovery', 'enlightened thought', 'enlightenment', 'epiphany', 'foresight', 'fresh perspective', 'grasp', 'grasping', 'holistic view', 'illumination', 'insight', 'insight-driven', 'insightful analysis', 'insightfulness', 'interpretation', 'introspection', 'intuition', 'intuitive grasp', 'judiciousness', 'keen observation', 'keenness', 'knowledge', 'lucidity', 'mental clarity', 'mindfulness', 'new angle', 'observance', 'observant', 'observation', 'paradigm shift', 'perception', 'perceptive', 'perceptive insight', 'perceptiveness', 'perspective', 'perspicacity', 'perspicuity', 'profound understanding', 'profundity', 'prudence', 'realization', 'realized', 'recognition', 'reflection', 'revelation', 'sagacity', 'self-awareness', 'self-knowledge', 'sharp awareness', 'sharpness', 'shrewdness', 'strategic insight', 'synthesis', 'thoughtful consideration', 'thoughtful insight', 'thoughtful reflection', 'understanding', 'wisdom', 'wise']
# Mindfulness: ['acceptance', 'acceptance practice', 'attention', 'attunement', 'awareness', 'awareness of breath', 'awareness of thoughts', 'awareness practice', 'balance', 'being', 'body scan', 'body-scan', 'breathing', 'calm', 'centeredness', 'centering', 'clarity', 'compassion', 'compassion practice', 'concentration', 'conscious', 'consciousness', 'curiosity', 'deep listening', 'detachment', 'dharma', 'emotional balance', 'emotional regulation', 'emotions', 'empathy', 'equanimity', 'flow', 'focus', 'gentle', 'gratitude', 'grounding', 'harmony', 'here and now', 'inner peace', 'insight', 'intention', 'intentional', 'intentionality', 'introspection', 'joy', 'kindness', 'letting go', 'listening', 'loving-kindness', 'mantra', 'meditate', 'meditation', 'mental clarity', 'metacognition', 'metta', 'mindful', 'mindful breathing', 'mindful eating', 'mindful listening', 'mindful movement', 'mindful walking', 'mindfulness', 'mindfulness-based', 'moment', 'moment to moment', 'nature', 'non-attachment', 'non-judgment', 'non-reactivity', 'nonattachment', 'nonjudgemental', 'nonreactive', 'nonreactivity', 'noticing', 'observance', 'observation', 'open-minded', 'openness', 'patience', 'peace', 'perception', 'poise', 'presence', 'present moment', 'present-focused', 'reflection', 'relaxation', 'resilience', 'self-awareness', 'self-care', 'self-compassion', 'self-inquiry', 'self-regulation', 'sensations', 'serenity', 'silence', 'simplicity', 'stillness', 'stress reduction', 'thoughts', 'tranquility', 'vipassana', 'visualization', 'yoga', 'zen']
# Compassion: ['acceptance', 'active listening', 'advocacy', 'affective empathy', 'altruism', 'attunement', 'benevolence', 'care', 'caring actions', 'charity', 'cognitive empathy', 'comfort', 'community', 'compassion', 'compassion fatigue', 'compassion in action', 'compassion meditation', 'compassion practice', 'compassion satisfaction', 'compassion training', 'compassion-driven', 'compassion-focused', 'compassion-focused therapy', 'compassionate communication', 'compassionate leadership', 'compassionately', 'connectedness', 'connection', 'emotional intelligence', 'emotional support', 'empathetic concern', 'empathic concern', 'empathy', 'empathy building', 'empathy fatigue', 'empathy gap', 'empathy training', 'encouragement', 'forgiveness', 'generosity', 'gentleness', 'goodwill', 'grace', 'gratitude', 'healing', 'heartfulness', 'help others', 'humanity', 'humility', 'kind', 'kindness', 'listening', 'love', 'loving-kindness', 'mercy', 'mindfulness', 'moral elevation', 'non-judgment', 'nonjudgmental', 'nurture', 'nurturing', 'outreach', 'outreach programs', 'patience', 'positive regard', 'presence', 'prosocial behavior', 'rapport', 'relational depth', 'resilience', 'respect', 'self-compassion', 'selflessness', 'sensitivity', 'service', 'shared experience', 'social responsibility', 'social support', 'solace', 'solidarity', 'support', 'sympathy', 'tenderness', 'togetherness', 'tolerance', 'trust', 'unconditional positive regard', 'understanding', 'uplift', 'validation', 'volunteerism', 'warmth', 'well-being']

# %% [markdown]
# Add or remove tokens in a list that definitely should /shouldn't be there. BE CAREFUL WITH TYPOS OR MISPELLINGS.
#
# In source you can add any additional description. Recommend putting your initials as well available in `my_lexicon.creator`.

# %%
print(my_lexicon.creator)
my_lexicon.add('Mindfulness', section ='tokens',value = ['meditate', 'pay attention'], source=my_lexicon.creator + ": added a few verb forms") # Up to you as an expert
my_lexicon.remove('Mindfulness', remove_tokens = ['being', 'flow'], source =my_lexicon.creator + ": might capture non-compassion-related context too often") # Up to you as an expert
# Out:
# DML

# %% [markdown]
# Now those appear as entries in the metadata. All additions are merged and all removed are removed

# %%
for n in my_lexicon.constructs['Mindfulness']['tokens_metadata'].keys():
	print('action: ', 
	my_lexicon.constructs['Mindfulness']['tokens_metadata'][n]['action'],
	'; from source: ',
	n)
# Out:
# action:  create ; from source:  gpt-4o-mini-2024-07-18, temperature-0.1, top_p-1, max_tokens-150, seed-42, 24-08-12T19-42-40.722780
# action:  create ; from source:  gpt-4o-2024-05-13, temperature-0, top_p-1, max_tokens-150, seed-42, 24-08-12T19-42-52.978642
# action:  create ; from source:  gpt-4o-2024-05-13, temperature-0.5, top_p-1, max_tokens-150, seed-42, 24-08-12T19-42-54.840277
# action:  create ; from source:  gpt-4o-2024-05-13, temperature-1, top_p-1, max_tokens-150, seed-42, 24-08-12T19-42-57.982166
# action:  manually added ; from source:  DML: added a few verb forms 24-08-12T19-43-07.454435
# action:  remove ; from source:  DML: might capture non-compassion-related context too often 24-08-12T19-43-07.456329

# %% [markdown]
# Or export to csv, rate spreadsheat and import back into python.
#
# See section "Validate with experts or just crowdsourcing" below on how to code and reload spreadsheet back into python

# %% [markdown]
# #### Lexicon step 1.4: Confirm additions and removals were successful.
#
# `['tokens']` contains the final tokens.

# %%
for construct in construct_information.keys():
	print(f"{construct}:",my_lexicon.constructs[construct]['tokens'])
# Out:
# Insight: ['acuity', 'acumen', 'aha moment', 'analysis', 'analytical thinking', 'astuteness', 'awareness', 'breakthrough', 'brilliance', 'clarity', 'clear vision', 'cognition', 'cognitive shift', 'comprehension', 'consciousness', 'contemplation', 'critical thinking', 'deduction', 'deep dive', 'deep understanding', 'depth', 'detection', 'discernment', 'discovery', 'enlightened thought', 'enlightenment', 'epiphany', 'foresight', 'fresh perspective', 'grasp', 'grasping', 'holistic view', 'illumination', 'insight', 'insight-driven', 'insightful analysis', 'insightfulness', 'interpretation', 'introspection', 'intuition', 'intuitive grasp', 'judiciousness', 'keen observation', 'keenness', 'knowledge', 'lucidity', 'mental clarity', 'mindfulness', 'new angle', 'observance', 'observant', 'observation', 'paradigm shift', 'perception', 'perceptive', 'perceptive insight', 'perceptiveness', 'perspective', 'perspicacity', 'perspicuity', 'profound understanding', 'profundity', 'prudence', 'realization', 'realized', 'recognition', 'reflection', 'revelation', 'sagacity', 'self-awareness', 'self-knowledge', 'sharp awareness', 'sharpness', 'shrewdness', 'strategic insight', 'synthesis', 'thoughtful consideration', 'thoughtful insight', 'thoughtful reflection', 'understanding', 'wisdom', 'wise']
# Mindfulness: ['acceptance', 'acceptance practice', 'attention', 'attunement', 'awareness', 'awareness of breath', 'awareness of thoughts', 'awareness practice', 'balance', 'body scan', 'body-scan', 'breathing', 'calm', 'centeredness', 'centering', 'clarity', 'compassion', 'compassion practice', 'concentration', 'conscious', 'consciousness', 'curiosity', 'deep listening', 'detachment', 'dharma', 'emotional balance', 'emotional regulation', 'emotions', 'empathy', 'equanimity', 'focus', 'gentle', 'gratitude', 'grounding', 'harmony', 'here and now', 'inner peace', 'insight', 'intention', 'intentional', 'intentionality', 'introspection', 'joy', 'kindness', 'letting go', 'listening', 'loving-kindness', 'mantra', 'meditate', 'meditation', 'mental clarity', 'metacognition', 'metta', 'mindful', 'mindful breathing', 'mindful eating', 'mindful listening', 'mindful movement', 'mindful walking', 'mindfulness', 'mindfulness-based', 'moment', 'moment to moment', 'nature', 'non-attachment', 'non-judgment', 'non-reactivity', 'nonattachment', 'nonjudgemental', 'nonreactive', 'nonreactivity', 'noticing', 'observance', 'observation', 'open-minded', 'openness', 'patience', 'pay attention', 'peace', 'perception', 'poise', 'presence', 'present moment', 'present-focused', 'reflection', 'relaxation', 'resilience', 'self-awareness', 'self-care', 'self-compassion', 'self-inquiry', 'self-regulation', 'sensations', 'serenity', 'silence', 'simplicity', 'stillness', 'stress reduction', 'thoughts', 'tranquility', 'vipassana', 'visualization', 'yoga', 'zen']
# Compassion: ['acceptance', 'active listening', 'advocacy', 'affective empathy', 'altruism', 'attunement', 'benevolence', 'care', 'caring actions', 'charity', 'cognitive empathy', 'comfort', 'community', 'compassion', 'compassion fatigue', 'compassion in action', 'compassion meditation', 'compassion practice', 'compassion satisfaction', 'compassion training', 'compassion-driven', 'compassion-focused', 'compassion-focused therapy', 'compassionate communication', 'compassionate leadership', 'compassionately', 'connectedness', 'connection', 'emotional intelligence', 'emotional support', 'empathetic concern', 'empathic concern', 'empathy', 'empathy building', 'empathy fatigue', 'empathy gap', 'empathy training', 'encouragement', 'forgiveness', 'generosity', 'gentleness', 'goodwill', 'grace', 'gratitude', 'healing', 'heartfulness', 'help others', 'humanity', 'humility', 'kind', 'kindness', 'listening', 'love', 'loving-kindness', 'mercy', 'mindfulness', 'moral elevation', 'non-judgment', 'nonjudgmental', 'nurture', 'nurturing', 'outreach', 'outreach programs', 'patience', 'positive regard', 'presence', 'prosocial behavior', 'rapport', 'relational depth', 'resilience', 'respect', 'self-compassion', 'selflessness', 'sensitivity', 'service', 'shared experience', 'social responsibility', 'social support', 'solace', 'solidarity', 'support', 'sympathy', 'tenderness', 'togetherness', 'tolerance', 'trust', 'unconditional positive regard', 'understanding', 'uplift', 'validation', 'volunteerism', 'warmth', 'well-being']

# %% [markdown]
# #### Lexicon step 1.5: Save preliminary lexicon

# %%
clean_lexicon_name = my_lexicon.name.replace(" ", "-")+'_v'+my_lexicon.version.replace('.', '-')

if google_drive:
  preprocessing_dir = f'{lexicon_dir}/{clean_lexicon_name}/preprocessing'

else:
  # local
  preprocessing_dir = f'{lexicon_dir}/{clean_lexicon_name}/preprocessing'

my_lexicon.save(preprocessing_dir) # may take a few minutes to appear on Google Drive
# Out:
# INFO: Saved lexicon to ./ct_lexicons//Insight_v1-0/preprocessing/Insight_24-08-12T19-43-07

# %% [markdown]
# For a given construct, you can review metadata, which contains the history of different actions (creating using Gen AI, adding, removing), which comes with a timestamp, the specific prompt used (including examples, definition, if any). All of these entries

# %%
import json
for construct in construct_information.keys():
	print("==="*30)
	print(construct)
	print()
	print(json.dumps(my_lexicon.constructs[construct]['tokens_metadata'], indent=4))
# Out:
# ==========================================================================================
# Insight
#
# {
#     "gpt-4o-mini-2024-07-18, temperature-0.1, top_p-1, max_tokens-150, seed-42, 24-08-12T19-42-38.357967": {
#         "action": "create",
#         "tokens": [
#             "aha moment",
#             "analysis",
#             "analytical thinking",
#             "astuteness",
#             "awareness",
#             "breakthrough",
#             "clarity",
#             "clear vision",
#             "cognitive shift",
#             "comprehension",
#             "contemplation",
#             "critical thinking",
#             "deduction",
#             "deep dive",
#             "deep understanding",
#             "discernment",
#             "discovery",
#             "enlightened thought",
#             "enlightenment",
#             "epiphany",
#             "foresight",
#             "fresh perspective",
#             "grasp",
#             "holistic view",
#             "insight",
#             "insight-driven",
#             "insightful analysis",
#             "insightfulness",
#             "interpretation",
#             "intuition",
#             "intuitive grasp",
#             "keen observation",
#             "knowledge",
#             "mental clarity",
#             "mindfulness",
#             "new angle",
#             "observation",
#             "paradigm shift",
#             "perception",
#             "perceptive insight",
#             "perspective",
#             "profound understanding",
#             "realized",
#             "recognition",
#             "reflection",
#             "revelation",
#             "sagacity",
#             "sharp awareness",
#             "strategic insight",
#             "synthesis",
#             "thoughtful consideration",
#             "thoughtful insight",
#             "thoughtful reflection",
#             "understanding",
#             "wisdom"
#         ],
#         "prompt": "Provide many single words and some short phrases (all in lower case unless the word is generally in upper case) related to insight. Each token should be separated by a semicolon. Do not return duplicate tokens. Do not provide any explanation or additional text beyond the tokens.\nHere are some examples (include these in the list): insight; realized",
#         "time_elapsed": 2.4
#     },
#     "gpt-4o-2024-05-13, temperature-0, top_p-1, max_tokens-150, seed-42, 24-08-12T19-42-44.868840": {
#         "action": "create",
#         "tokens": [
#             "acuity",
#             "acumen",
#             "astuteness",
#             "awareness",
#             "brilliance",
#             "clarity",
#             "cognition",
#             "comprehension",
#             "consciousness",
#             "discernment",
#             "enlightenment",
#             "epiphany",
#             "foresight",
#             "grasp",
#             "insightfulness",
#             "introspection",
#             "intuition",
#             "keenness",
#             "knowledge",
#             "lucidity",
#             "mindfulness",
#             "observance",
#             "observant",
#             "perception",
#             "perceptive",
#             "perspicacity",
#             "realization",
#             "recognition",
#             "reflection",
#             "revelation",
#             "sagacity",
#             "self-awareness",
#             "sharpness",
#             "shrewdness",
#             "understanding",
#             "wisdom",
#             "wise"
#         ],
#         "prompt": "Provide many single words and some short phrases (all in lower case unless the word is generally in upper case) related to Insight (in the psychology domain). Each token should be separated by a semicolon. Do not return duplicate tokens. Do not provide any explanation or additional text beyond the tokens.\nHere is a definition of Insight: the clarity of understanding of one's thoughts, feelings and behavior\nHere are some examples (include these in the list): clarity; enlightenment; wise",
#         "time_elapsed": 2.2
#     },
#     "gpt-4o-2024-05-13, temperature-0.5, top_p-1, max_tokens-150, seed-42, 24-08-12T19-42-47.102237": {
#         "action": "create",
#         "tokens": [
#             "acuity",
#             "acumen",
#             "awareness",
#             "clarity",
#             "cognition",
#             "comprehension",
#             "consciousness",
#             "depth",
#             "discernment",
#             "enlightenment",
#             "epiphany",
#             "foresight",
#             "grasp",
#             "illumination",
#             "insightfulness",
#             "introspection",
#             "intuition",
#             "keenness",
#             "lucidity",
#             "mindfulness",
#             "observation",
#             "perception",
#             "perceptiveness",
#             "perspicacity",
#             "perspicuity",
#             "profundity",
#             "realization",
#             "recognition",
#             "revelation",
#             "sagacity",
#             "self-awareness",
#             "self-knowledge",
#             "shrewdness",
#             "understanding",
#             "wisdom",
#             "wise"
#         ],
#         "prompt": "Provide many single words and some short phrases (all in lower case unless the word is generally in upper case) related to Insight (in the psychology domain). Each token should be separated by a semicolon. Do not return duplicate tokens. Do not provide any explanation or additional text beyond the tokens.\nHere is a definition of Insight: the clarity of understanding of one's thoughts, feelings and behavior\nHere are some examples (include these in the list): clarity; enlightenment; wise",
#         "time_elapsed": 2.2
#     },
#     "gpt-4o-2024-05-13, temperature-1, top_p-1, max_tokens-150, seed-42, 24-08-12T19-42-49.254632": {
#         "action": "create",
#         "tokens": [
#             "acuity",
#             "awareness",
#             "brilliance",
#             "clarity",
#             "cognition",
#             "comprehension",
#             "consciousness",
#             "depth",
#             "detection",
#             "discernment",
#             "enlightenment",
#             "epiphany",
#             "foresight",
#             "grasp",
#             "grasping",
#             "insightfulness",
#             "introspection",
#             "intuition",
#             "judiciousness",
#             "keenness",
#             "lucidity",
#             "mindfulness",
#             "observance",
#             "observation",
#             "perception",
#             "perceptiveness",
#             "perspective",
#             "perspicacity",
#             "perspicuity",
#             "prudence",
#             "realization",
#             "recognition",
#             "revelation",
#             "sagacity",
#             "self-awareness",
#             "shrewdness",
#             "understanding",
#             "wisdom",
#             "wise"
#         ],
#         "prompt": "Provide many single words and some short phrases (all in lower case unless the word is generally in upper case) related to Insight (in the psychology domain). Each token should be separated by a semicolon. Do not return duplicate tokens. Do not provide any explanation or additional text beyond the tokens.\nHere is a definition of Insight: the clarity of understanding of one's thoughts, feelings and behavior\nHere are some examples (include these in the list): clarity; enlightenment; wise",
#         "time_elapsed": 1.9
#     }
# }
# ==========================================================================================
# Mindfulness
#
# {
#     "gpt-4o-mini-2024-07-18, temperature-0.1, top_p-1, max_tokens-150, seed-42, 24-08-12T19-42-40.722780": {
#         "action": "create",
#         "tokens": [
#             "acceptance",
#             "acceptance practice",
#             "attention",
#             "awareness",
#             "awareness of breath",
#             "awareness of thoughts",
#             "awareness practice",
#             "balance",
#             "body scan",
#             "breathing",
#             "calm",
#             "centering",
#             "clarity",
#             "compassion",
#             "compassion practice",
#             "deep listening",
#             "detachment",
#             "emotions",
#             "equanimity",
#             "flow",
#             "focus",
#             "gratitude",
#             "grounding",
#             "here and now",
#             "inner peace",
#             "insight",
#             "intention",
#             "joy",
#             "letting go",
#             "loving-kindness",
#             "mantra",
#             "meditate",
#             "mindful eating",
#             "mindful listening",
#             "mindful walking",
#             "mindfulness",
#             "moment",
#             "nature",
#             "non-judgment",
#             "non-reactivity",
#             "observation",
#             "presence",
#             "present moment",
#             "reflection",
#             "relaxation",
#             "resilience",
#             "self-awareness",
#             "self-care",
#             "self-compassion",
#             "sensations",
#             "silence",
#             "simplicity",
#             "stillness",
#             "stress reduction",
#             "thoughts",
#             "tranquility",
#             "visualization",
#             "yoga"
#         ],
#         "prompt": "Provide many single words and some short phrases (all in lower case unless the word is generally in upper case) related to mindfulness. Each token should be separated by a semicolon. Do not return duplicate tokens. Do not provide any explanation or additional text beyond the tokens.\nHere are some examples (include these in the list): mindfulness; meditate",
#         "time_elapsed": 2.1
#     },
#     "gpt-4o-2024-05-13, temperature-0, top_p-1, max_tokens-150, seed-42, 24-08-12T19-42-52.978642": {
#         "action": "create",
#         "tokens": [
#             "acceptance",
#             "attention",
#             "awareness",
#             "body scan",
#             "breathing",
#             "calm",
#             "centering",
#             "clarity",
#             "compassion",
#             "concentration",
#             "curiosity",
#             "dharma",
#             "emotional regulation",
#             "empathy",
#             "equanimity",
#             "flow",
#             "focus",
#             "gratitude",
#             "grounding",
#             "here and now",
#             "inner peace",
#             "insight",
#             "intentionality",
#             "introspection",
#             "kindness",
#             "loving-kindness",
#             "meditation",
#             "metta",
#             "mindful",
#             "mindful breathing",
#             "mindful eating",
#             "mindful listening",
#             "mindful movement",
#             "mindful walking",
#             "mindfulness-based",
#             "nonattachment",
#             "nonjudgemental",
#             "nonreactive",
#             "observation",
#             "openness",
#             "patience",
#             "perception",
#             "presence",
#             "present-focused",
#             "reflection",
#             "relaxation",
#             "resilience",
#             "self-awareness",
#             "self-compassion",
#             "self-inquiry",
#             "serenity",
#             "stillness",
#             "stress reduction",
#             "tranquility",
#             "vipassana",
#             "zen"
#         ],
#         "prompt": "Provide many single words and some short phrases (all in lower case unless the word is generally in upper case) related to Mindfulness (in the psychology domain). Each token should be separated by a semicolon. Do not return duplicate tokens. Do not provide any explanation or additional text beyond the tokens.\nHere is a definition of Mindfulness: mindfulness is the psychological process of bringing one's attention to experiences occurring in the present moment, which can be developed through the practice of meditation and other training.\nHere are some examples (include these in the list): mindful; meditation; awareness; nonjudgemental; present-focused",
#         "time_elapsed": 1.9
#     },
#     "gpt-4o-2024-05-13, temperature-0.5, top_p-1, max_tokens-150, seed-42, 24-08-12T19-42-54.840277": {
#         "action": "create",
#         "tokens": [
#             "acceptance",
#             "attention",
#             "attunement",
#             "awareness",
#             "balance",
#             "being",
#             "body scan",
#             "breathing",
#             "calm",
#             "centeredness",
#             "clarity",
#             "compassion",
#             "concentration",
#             "conscious",
#             "dharma",
#             "emotional balance",
#             "empathy",
#             "equanimity",
#             "focus",
#             "grounding",
#             "harmony",
#             "here and now",
#             "insight",
#             "intentional",
#             "introspection",
#             "letting go",
#             "meditation",
#             "mental clarity",
#             "metta",
#             "mindful",
#             "mindfulness-based",
#             "moment to moment",
#             "non-attachment",
#             "nonjudgemental",
#             "nonreactive",
#             "noticing",
#             "observation",
#             "open-minded",
#             "patience",
#             "peace",
#             "poise",
#             "presence",
#             "present-focused",
#             "reflection",
#             "relaxation",
#             "resilience",
#             "self-awareness",
#             "self-compassion",
#             "self-regulation",
#             "serenity",
#             "stillness",
#             "stress reduction",
#             "tranquility",
#             "vipassana",
#             "zen"
#         ],
#         "prompt": "Provide many single words and some short phrases (all in lower case unless the word is generally in upper case) related to Mindfulness (in the psychology domain). Each token should be separated by a semicolon. Do not return duplicate tokens. Do not provide any explanation or additional text beyond the tokens.\nHere is a definition of Mindfulness: mindfulness is the psychological process of bringing one's attention to experiences occurring in the present moment, which can be developed through the practice of meditation and other training.\nHere are some examples (include these in the list): mindful; meditation; awareness; nonjudgemental; present-focused",
#         "time_elapsed": 3.1
#     },
#     "gpt-4o-2024-05-13, temperature-1, top_p-1, max_tokens-150, seed-42, 24-08-12T19-42-57.982166": {
#         "action": "create",
#         "tokens": [
#             "acceptance",
#             "attention",
#             "attunement",
#             "awareness",
#             "balance",
#             "being",
#             "body-scan",
#             "breathing",
#             "calm",
#             "centeredness",
#             "clarity",
#             "compassion",
#             "consciousness",
#             "detachment",
#             "empathy",
#             "equanimity",
#             "focus",
#             "gentle",
#             "gratitude",
#             "grounding",
#             "harmony",
#             "here and now",
#             "insight",
#             "intention",
#             "introspection",
#             "kindness",
#             "listening",
#             "meditation",
#             "metacognition",
#             "mindful",
#             "mindfulness",
#             "nonjudgemental",
#             "nonreactivity",
#             "noticing",
#             "observance",
#             "observation",
#             "openness",
#             "patience",
#             "perception",
#             "presence",
#             "present-focused",
#             "reflection",
#             "resilience",
#             "self-awareness",
#             "self-care",
#             "self-regulation",
#             "serenity",
#             "stillness",
#             "tranquility"
#         ],
#         "prompt": "Provide many single words and some short phrases (all in lower case unless the word is generally in upper case) related to Mindfulness (in the psychology domain). Each token should be separated by a semicolon. Do not return duplicate tokens. Do not provide any explanation or additional text beyond the tokens.\nHere is a definition of Mindfulness: mindfulness is the psychological process of bringing one's attention to experiences occurring in the present moment, which can be developed through the practice of meditation and other training.\nHere are some examples (include these in the list): mindful; meditation; awareness; nonjudgemental; present-focused",
#         "time_elapsed": 2.5
#     },
#     "DML: added a few verb forms 24-08-12T19-43-07.454435": {
#         "action": "manually added",
#         "tokens": [
#             "meditate",
#             "pay attention"
#         ]
#     },
#     "DML: might capture non-compassion-related context too often 24-08-12T19-43-07.456329": {
#         "action": "remove",
#         "tokens": [
#             "being",
#             "flow"
#         ]
#     }
# }
# ==========================================================================================
# Compassion
#
# {
#     "gpt-4o-mini-2024-07-18, temperature-0.1, top_p-1, max_tokens-150, seed-42, 24-08-12T19-42-42.843959": {
#         "action": "create",
#         "tokens": [
#             "acceptance",
#             "active listening",
#             "advocacy",
#             "altruism",
#             "benevolence",
#             "care",
#             "caring actions",
#             "charity",
#             "comfort",
#             "community",
#             "compassion",
#             "compassion fatigue",
#             "compassion in action",
#             "compassion meditation",
#             "compassion practice",
#             "compassion training",
#             "compassion-driven",
#             "compassion-focused",
#             "compassionate communication",
#             "compassionate leadership",
#             "compassionately",
#             "connection",
#             "emotional support",
#             "empathy",
#             "empathy building",
#             "encouragement",
#             "forgiveness",
#             "generosity",
#             "goodwill",
#             "healing",
#             "heartfulness",
#             "help others",
#             "humanity",
#             "kind",
#             "kindness",
#             "listening",
#             "love",
#             "loving-kindness",
#             "mindfulness",
#             "non-judgment",
#             "nurturing",
#             "outreach",
#             "outreach programs",
#             "patience",
#             "presence",
#             "respect",
#             "selflessness",
#             "service",
#             "shared experience",
#             "social responsibility",
#             "solace",
#             "support",
#             "sympathy",
#             "tenderness",
#             "togetherness",
#             "understanding",
#             "uplift",
#             "volunteerism",
#             "warmth"
#         ],
#         "prompt": "Provide many single words and some short phrases (all in lower case unless the word is generally in upper case) related to compassion. Each token should be separated by a semicolon. Do not return duplicate tokens. Do not provide any explanation or additional text beyond the tokens.\nHere are some examples (include these in the list): compassion; love; kind; help others",
#         "time_elapsed": 1.9
#     },
#     "gpt-4o-2024-05-13, temperature-0, top_p-1, max_tokens-150, seed-42, 24-08-12T19-43-00.583562": {
#         "action": "create",
#         "tokens": [
#             "acceptance",
#             "altruism",
#             "benevolence",
#             "care",
#             "charity",
#             "comfort",
#             "compassion",
#             "compassion fatigue",
#             "compassion meditation",
#             "compassion satisfaction",
#             "compassion training",
#             "compassion-focused therapy",
#             "connection",
#             "emotional intelligence",
#             "emotional support",
#             "empathic concern",
#             "empathy",
#             "empathy fatigue",
#             "encouragement",
#             "forgiveness",
#             "generosity",
#             "gentleness",
#             "gratitude",
#             "healing",
#             "help others",
#             "humanity",
#             "humility",
#             "kind",
#             "kindness",
#             "listening",
#             "love",
#             "loving-kindness",
#             "mercy",
#             "mindfulness",
#             "nonjudgmental",
#             "nurturing",
#             "patience",
#             "positive regard",
#             "presence",
#             "prosocial behavior",
#             "resilience",
#             "respect",
#             "self-compassion",
#             "selflessness",
#             "sensitivity",
#             "social support",
#             "solace",
#             "solidarity",
#             "support",
#             "sympathy",
#             "tolerance",
#             "trust",
#             "unconditional positive regard",
#             "understanding",
#             "validation",
#             "warmth",
#             "well-being"
#         ],
#         "prompt": "Provide many single words and some short phrases (all in lower case unless the word is generally in upper case) related to Compassion (in the psychology domain). Each token should be separated by a semicolon. Do not return duplicate tokens. Do not provide any explanation or additional text beyond the tokens.\nHere are some examples (include these in the list): compassion; love; kind; help others",
#         "time_elapsed": 2.7
#     },
#     "gpt-4o-2024-05-13, temperature-0.5, top_p-1, max_tokens-150, seed-42, 24-08-12T19-43-03.280720": {
#         "action": "create",
#         "tokens": [
#             "acceptance",
#             "active listening",
#             "altruism",
#             "attunement",
#             "benevolence",
#             "care",
#             "charity",
#             "comfort",
#             "compassion",
#             "compassion fatigue",
#             "connection",
#             "emotional intelligence",
#             "emotional support",
#             "empathetic concern",
#             "empathy",
#             "empathy fatigue",
#             "empathy gap",
#             "encouragement",
#             "forgiveness",
#             "generosity",
#             "gentleness",
#             "grace",
#             "healing",
#             "help others",
#             "humanity",
#             "humility",
#             "kind",
#             "kindness",
#             "love",
#             "mercy",
#             "mindfulness",
#             "moral elevation",
#             "nonjudgmental",
#             "nurture",
#             "patience",
#             "presence",
#             "prosocial behavior",
#             "rapport",
#             "relational depth",
#             "respect",
#             "selflessness",
#             "sensitivity",
#             "solace",
#             "solidarity",
#             "support",
#             "sympathy",
#             "tolerance",
#             "trust",
#             "unconditional positive regard",
#             "understanding",
#             "validation",
#             "warmth"
#         ],
#         "prompt": "Provide many single words and some short phrases (all in lower case unless the word is generally in upper case) related to Compassion (in the psychology domain). Each token should be separated by a semicolon. Do not return duplicate tokens. Do not provide any explanation or additional text beyond the tokens.\nHere are some examples (include these in the list): compassion; love; kind; help others",
#         "time_elapsed": 2.5
#     },
#     "gpt-4o-2024-05-13, temperature-1, top_p-1, max_tokens-150, seed-42, 24-08-12T19-43-05.823341": {
#         "action": "create",
#         "tokens": [
#             "acceptance",
#             "active listening",
#             "affective empathy",
#             "altruism",
#             "benevolence",
#             "care",
#             "cognitive empathy",
#             "comfort",
#             "compassion",
#             "connectedness",
#             "emotional intelligence",
#             "emotional support",
#             "empathy",
#             "empathy training",
#             "encouragement",
#             "forgiveness",
#             "generosity",
#             "gentleness",
#             "healing",
#             "help others",
#             "humanity",
#             "kind",
#             "kindness",
#             "love",
#             "mercy",
#             "mindfulness",
#             "non-judgment",
#             "nurture",
#             "patience",
#             "positive regard",
#             "prosocial behavior",
#             "self-compassion",
#             "solace",
#             "support",
#             "sympathy",
#             "tenderness",
#             "understanding",
#             "warmth",
#             "well-being"
#         ],
#         "prompt": "Provide many single words and some short phrases (all in lower case unless the word is generally in upper case) related to Compassion (in the psychology domain). Each token should be separated by a semicolon. Do not return duplicate tokens. Do not provide any explanation or additional text beyond the tokens.\nHere are some examples (include these in the list): compassion; love; kind; help others",
#         "time_elapsed": 1.6
#     }
# }

# %% [markdown]
# Also available in `_metadata.json` file when saving the lexicon

# %% [markdown]
# #### Lexicon step 1.6: Extract counts
#
# Calibration step: this can be done on a examples you come up with or on training set to make sure it's doing a good job

# %%
# Now count whether tokens appear in document:

counts, matches_by_construct, matches_doc2construct, matches_construct2doc  = my_lexicon.extract(documents,
                                                                                      normalize = False,
                                                                                      )
display(counts)
# Out:
# extracting...
#   0%|          | 0/3 [00:00<?, ?it/s]WARNING: Lemmatizing the tokens. We recommend you lemmatize before extracting so you can save time if you want to repeat extraction on different documents.
#  33%|███▎      | 1/3 [00:00<00:01,  1.66it/s]WARNING: Lemmatizing the tokens. We recommend you lemmatize before extracting so you can save time if you want to repeat extraction on different documents.
#  67%|██████▋   | 2/3 [00:01<00:00,  1.77it/s]WARNING: Lemmatizing the tokens. We recommend you lemmatize before extracting so you can save time if you want to repeat extraction on different documents.
# 100%|██████████| 3/3 [00:01<00:00,  1.75it/s]
#    document_id                                           document  Insight  \
# 0            0  Every time I speak with my cousin Bob, I have ...        3
# 1            1       He meditates a lot, but he's not super smart        0
# 2            2                              He is too competitive        0
#
#    Mindfulness  Compassion  word_count
# 0            3           0          17
# 1            1           0           8
# 2            0           0           4

# %%
# Interpret counts: visualize matches in context  

show_n_sentences = 2 # up to this amount
for construct in construct_information.keys():
	print(f'------- Matches for {construct}:')
	lexicon.highlight_matches(documents, construct,show_n_sentences, matches_construct2doc)
	print()
# Out:
# ------- Matches for Insight:
# Every time I speak with my cousin Bob, I have great moments of <mark>insight</mark>, <mark>clarity</mark>, and <mark>wisdom</mark>
# ------- Matches for Mindfulness:
# He <mark>meditate</mark>s a lot, but he's not super smart
# Every time I speak with my cousin Bob, I have great <mark>moment</mark>s of <mark>insight</mark>, <mark>clarity</mark>, and wisdom
# ------- Matches for Compassion:

# %% [markdown]
# #### Lexicon step 1.7: Validate with experts or just crowdsourcing (OPTIONAL)
#
# 1.7.1. Create `human_ratings/` folder

# %%
perform_human_ratings = False

if perform_human_ratings:
	clean_lexicon_name = my_lexicon.name.replace(" ", "-")+'_v'+my_lexicon.version.replace('.', '-')

	if google_drive:
		preprocessing_dir = f'{lexicon_dir}/{clean_lexicon_name}/human_ratings'

	else:
		# local
		ratings_dir = f'{lexicon_dir}/{clean_lexicon_name}/human_ratings/' 



	os.makedirs(ratings_dir, exist_ok=True)

# %% [markdown]
# 1.7.2. Take the `<date>_ratings.csv` in the `preprocessing/` directory and send a copy to each human rater (aka coder, annotator) with their ID appended to the filename. Here we'll automatically find the last one created.

# %%
if perform_human_ratings:

	# I'll create three duplicates of the ratings file identifying each file with raters initiails

	# or use digit IDs:
	n_raters = 3
	rater_ids = [str(i).zfill(3) for i in range(n_raters)] # ['001', '002', '003']
	# Save names for each ID separately in case you need to check in about a certain rating. 


	copy_annotation_file_to_ratings_dir = False

	if copy_annotation_file_to_ratings_dir:
		path_to_unvalidated_lexicon = os.listdir(preprocessing_dir)
		path_to_unvalidated_lexicon = [n for n in path_to_unvalidated_lexicon if n.endswith('ratings.csv')][0]

		for rater_id in rater_ids:
			new_path = path_to_unvalidated_lexicon.replace('preprocessing', 'human_ratings').replace('.csv', f'_{rater_id}.csv')
			# copy from preprocessing to human_raters
			shutil.copy(path_to_unvalidated_lexicon, new_path)


	# Now you have this file in human_ratings Insight_24-08-08T21-29-52_ratings_DLC.csv etc.

# %% [markdown]
# 1.7.3. Have them rate following these or similar instructions. Save files as csv instead of excel to use the code below
#
# https://github.com/danielmlow/construct-tracker/blob/daniels_branch/tutorials/lexicon%20risk%20factors%20final%20instructions.pdf
#
# [Google docs version](https://docs.google.com/document/d/1pu89KmU31grhzFeZmwOoN0U2plSWaDMSKWYUXy_acL4/edit?usp=sharing)
#
# In this toy example, I just duplicated the files as an example so they all have the same ratings. One of the raters added some suggestions. The instructions can take them as 3/3 or the rater can add them at the bottom and can add their rating. Then these can be sent to other raters in a second round before going onto the next step.

# %% [markdown]
# 1.7.4. Take average ratings, discard tokens below a certain average

# %%
ratings_dir
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/6f/x95fldf13xn_k25tybdzgtqw0000gn/T/ipykernel_50360/269600391.py in <cell line: 0>()
# ----> 1 ratings_dir
#
# NameError: name 'ratings_dir' is not defined

# %%
# average_ratings

rating_files = os.listdir(ratings_dir)
rating_files = [n for n in rating_files if n not in ['.DS_Store']]
print(rating_files) # this should not be empty, you should have some human_rating files for each rater
# Out:
# ['Insight_24-08-08T21-29-52_ratings_002.csv', 'Insight_24-08-08T21-29-52_ratings_003.csv', 'Insight_24-08-08T21-29-52_ratings_001.csv']

# %%
if perform_human_ratings:
	from construct_tracker.lexicon import avg_above_thresh, merge_rating_dfs

	# Copy and paste correct files here to make sure you don't add the same ratings with two different extensions:
	rating_files = [
		'Insight_24-08-08T21-29-52_ratings_002.csv', 'Insight_24-08-08T21-29-52_ratings_003.csv', 'Insight_24-08-08T21-29-52_ratings_001.csv'
		]

	# Ratings by all raters in a single dictionary
	# all_ratings_per_construct_dict = {
		# construct_1: {token_1: [rating_1, rating_2, ...], token_2: [rating_1, rating_2, ...], ...},
		# construct_2: {token_1: [rating_1, rating_2, ...], token_2: [rating_1, rating_2, ...], ...},
		# ...} 

	all_ratings_per_construct_dict = merge_rating_dfs(ratings_dir, rating_files, construct_information.keys())

	# Save ratings to lexicon
	todays_date = datetime.datetime.utcnow().strftime("%y-%m-%d") 
	my_lexicon.set_attribute('ratings_'+todays_date, all_ratings_per_construct_dict)

# %%
if perform_human_ratings:
	# Average and remove tokens < a threshold
	ratings_avg, ratings_removed = lexicon.avg_above_thresh(all_ratings_per_construct_dict, thresh = 1.3)

	# Remove tokens with low avg. ratings
	for construct in ratings_removed:
		remove_tokens = ratings_removed[construct]
		my_lexicon.remove(construct, remove_tokens=remove_tokens, 
						source = my_lexicon.creator + ": tokens rated lower than 1.3 by raters")

# %%
if perform_human_ratings:

	# Average and only keep tokens 3/3 on protoypicality. These are definitely related to the construct and can be used for CTS or to avoid false positives. 
	ratings_avg_prototypical, ratings_removed_prototypical = lexicon.avg_above_thresh(all_ratings_per_construct_dict, thresh = 3) # set to 3 or perhaps above 2 like 2.1. 

	my_lexicon_prototypes = copy.deepcopy(my_lexicon)
	my_lexicon_prototypes.name = my_lexicon.name + ' prototypes'

	# Remove tokens with low avg. ratings
	for construct in ratings_removed_prototypical:
		remove_tokens = ratings_removed[construct]
		my_lexicon_prototypes.remove(construct, remove_tokens=remove_tokens, 
									source = my_lexicon_prototypes.creator + ": tokens rated lower than 3 by raters")



	# Save final prototypes lexicon
	
	my_lexicon_prototypes.save(f'{lexicon_dir}/{clean_lexicon_name}/', filename = 'suicide_risk_lexicon_validated_prototypes-3-3') # save lexicon protocotypes 3/3
# Out:
# INFO: Saved lexicon to ./ct_lexicons//Insight_v1-0//suicide_risk_lexicon_validated_prototypes-3-3_24-08-12T17-53-07

# %%
if perform_human_ratings:
	# List construct with less than 10 tokens (which might be too few for a lexicon but sufficient for CTS method). [] means none.
	print([(k,v) for k,v in ratings_avg_prototypical.items() if len(v)<10])
# Out:
# []

# %% [markdown]
# 1.7.5. Inter-rater reliability (OPTIONAL)
#
# 	See manuscript for more information

# %%
if perform_human_ratings:
	from construct_tracker.utils import irr
	import numpy as np
	from sklearn.metrics import cohen_kappa_score


	# df = all_ratings_per_construct_dict
	# or from: all_ratings_per_construct_dict = my_lexicon.get_attribute('ratings_24-08-08')

	# TODO: turn into function
	cohens_kappa_all = {}
	fleiss_kappa_all = {}
	for construct, tokens in all_ratings_per_construct_dict.items():
		construct_c_ratings = list(tokens.values())
		construct_c_ratings_mode = int(np.median([len(n) for n in construct_c_ratings])) # construct_c_ratings)
		construct_c_ratings_all_annotated = []
		for token_i_ratings in construct_c_ratings:
			token_i_ratings = list(token_i_ratings)
		
			
			if len(token_i_ratings)==construct_c_ratings_mode and np.mean(token_i_ratings)>1.3:
			# 	token_i_ratings = token_i_ratings + [np.round(np.mean(token_i_ratings),0)]

				construct_c_ratings_all_annotated.append(token_i_ratings)
				
		# If I dont have them all the same shape, can't calculate
		construct_c_ratings = np.array(construct_c_ratings_all_annotated)
		construct_c_ratings = construct_c_ratings.astype(int)
		
		if construct_c_ratings.shape[1] == 2:
			# kappa = binary_inter_rater_reliability(construct_c_ratings[:,0], construct_c_ratings[:,1])
			kappa = irr.cohens_kappa(construct_c_ratings)
			cohens_kappa_all[construct.replace('_include','')] = kappa
			print(f"Cohen's Weighted Kappa (2 raters) for {construct}: {kappa}")
		elif construct_c_ratings.shape[1] >= 3:
			kappa = irr.calculate_fleiss_kappa(construct_c_ratings)
			fleiss_kappa_all[construct.replace('_include','')] = kappa
			print(f"Fleiss' Kappa (3 or more raters) for {construct}: {kappa}")


	weighted_kappa = pd.DataFrame(cohens_kappa_all, index = ['weighted_kappa']).T.mean()
	fleis_kappa = pd.DataFrame(fleiss_kappa_all, index = ['fleiss_kappa']).T


	display(weighted_kappa)
	display(fleis_kappa)
# Out:
# Fleiss' Kappa (3 or more raters) for Insight: 1.0
# Fleiss' Kappa (3 or more raters) for Mindfulness: 1.0
# Fleiss' Kappa (3 or more raters) for Compassion: 1.0
# weighted_kappa   NaN
# dtype: float64
#              fleiss_kappa
# Insight               1.0
# Mindfulness           1.0
# Compassion            1.0

# %% [markdown]
# #### Lexicon step 1.8: Save final lexicon

# %%
# Main lexicon
my_lexicon.save(f'{lexicon_dir}/{clean_lexicon_name}/', filename = 'suicide_risk_lexicon_validated') # save lexicon
# Out:
# INFO: Saved lexicon to ./ct_lexicons//Insight_v1-0//suicide_risk_lexicon_validated_24-08-12T17-49-12

# %% [markdown]
# #### Lexicon step 1.9: Final feature extraction
#
# If you want to load lexicon in a different script in the future:
# ```python
# path = f'./ct_lexicons/{clean_lexicon_name}/'
# my_lexicon = load_lexicon(path)
# ```

# %%
# Now count whether tokens appear in document:

normalize = True
# We'll set normalize to True. Whether to normalize the extracted features by word count. 3 matches in a short document would be weighed higher than in a long document.
counts, matches_by_construct, matches_doc2construct, matches_construct2doc  = my_lexicon.extract(documents,
                                                                                      normalize = normalize,
                                                                                      )
display(counts)
# Might be worth calibrating (removing words that create false positives too often) on a training set.
# Out:
# extracting...
#   0%|          | 0/3 [00:00<?, ?it/s]WARNING: Lemmatizing the tokens. We recommend you lemmatize before extracting so you can save time if you want to repeat extraction on different documents.
#  33%|███▎      | 1/3 [00:00<00:01,  1.82it/s]WARNING: Lemmatizing the tokens. We recommend you lemmatize before extracting so you can save time if you want to repeat extraction on different documents.
#  67%|██████▋   | 2/3 [00:01<00:00,  1.81it/s]WARNING: Lemmatizing the tokens. We recommend you lemmatize before extracting so you can save time if you want to repeat extraction on different documents.
# 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
#    document_id                                           document   Insight  \
# 0            0  Every time I speak with my cousin Bob, I have ...  0.176471
# 1            1       He meditates a lot, but he's not super smart  0.000000
# 2            2                              He is too competitive  0.000000
#
#    Mindfulness  Compassion  word_count
# 0     0.117647         0.0          17
# 1     0.125000         0.0           8
# 2     0.000000         0.0           4

# %%
# save counts
output_dir = './data/insight_project/'
os.makedirs(output_dir, exist_ok=True)
counts.to_csv(f'{output_dir}insight_lexicon_counts_normalize-{normalize}.csv', index = False)

# %% [markdown]
# ## 2. Construct-Text Similarity (CTS)

# %% [markdown]
# #### CTS step 2.1: Load validated lexicon or create your a quick one with some keywords

# %%
# Here you can use my_lexicon or my_lexicon_prototypes (so it doesn't find similarity with too many low-prototypical tokens)
lexicon_dict = my_lexicon.to_dict() 
lexicon_dict
# Out:
# {'Insight': ['aha moment',
#   'analytical thinking',
#   'astuteness',
#   'awareness',
#   'breakthrough',
#   'clarity',
#   'clarity of thought',
#   'clear vision',
#   'cognitive insight',
#   'comprehension',
#   'conceptual insight',
#   'contemplation',
#   'critical thinking',
#   'deep insight',
#   'deep understanding',
#   'diagnosis',
#   'diagnostic insight',
#   'discernment',
#   'discovery',
#   'enlightened perspective',
#   'enlightenment',
#   'epiphany',
#   'foresight',
#   'grasp',
#   'grasping',
#   'illumination',
#   'informed decision',
#   'insight',
#   'insight-driven',
#   'insightful',
#   'insightful analysis',
#   'insightfulness',
#   'introspection',
#   'introspective',
#   'intuition',
#   'intuitive grasp',
#   'keen perception',
#   'knowledge',
#   'knowledgeable',
#   'lucidity',
#   'meaningful understanding',
#   'mental clarity',
#   'mindful',
#   'mindfulness',
#   'perception',
#   'perceptive',
#   'perceptive insight',
#   'perceptive understanding',
#   'perceptiveness',
#   'perceptivity',
#   'perspective',
#   'perspicacity',
#   'perspicuity',
#   'profound realization',
#   'profound understanding',
#   'psychological insight',
#   'realization',
#   'realized',
#   'recognition',
#   'reflection',
#   'reflective thinking',
#   'revelation',
#   'sagacity',
#   'self-awareness',
#   'self-knowledge',
#   'sharp awareness',
#   'shrewdness',
#   'situational awareness',
#   'strategic insight',
#   'thoughtful analysis',
#   'thoughtful observation',
#   'thoughtful reflection',
#   'transformative understanding',
#   'understanding',
#   'wisdom',
#   'wise',
#   'aha moment',
#   'analytical thinking',
#   'astuteness',
#   'awareness',
#   'breakthrough',
#   'clarity',
#   'clarity of thought',
#   'clear vision',
#   'cognitive insight',
#   'comprehension',
#   'conceptual insight',
#   'contemplation',
#   'critical thinking',
#   'deep insight',
#   'deep understanding',
#   'diagnosis',
#   'diagnostic insight',
#   'discernment',
#   'discovery',
#   'enlighten perspective',
#   'enlightenment',
#   'epiphany',
#   'foresight',
#   'grasp',
#   'grasp',
#   'illumination',
#   'inform decision',
#   'insight',
#   'insight - drive',
#   'insightful',
#   'insightful analysis',
#   'insightfulness',
#   'introspection',
#   'introspective',
#   'intuition',
#   'intuitive grasp',
#   'keen perception',
#   'knowledge',
#   'knowledgeable',
#   'lucidity',
#   'meaningful understanding',
#   'mental clarity',
#   'mindful',
#   'mindfulness',
#   'perception',
#   'perceptive',
#   'perceptive insight',
#   'perceptive understanding',
#   'perceptiveness',
#   'perceptivity',
#   'perspective',
#   'perspicacity',
#   'perspicuity',
#   'profound realization',
#   'profound understanding',
#   'psychological insight',
#   'realization',
#   'realize',
#   'recognition',
#   'reflection',
#   'reflective thinking',
#   'revelation',
#   'sagacity',
#   'self - awareness',
#   'self - knowledge',
#   'sharp awareness',
#   'shrewdness',
#   'situational awareness',
#   'strategic insight',
#   'thoughtful analysis',
#   'thoughtful observation',
#   'thoughtful reflection',
#   'transformative understanding',
#   'understand',
#   'wisdom',
#   'wise'],
#  'Mindfulness': ['acceptance',
#   'acceptance and commitment',
#   'attention',
#   'attentiveness',
#   'attunement',
#   'awareness',
#   'awareness of breath',
#   'awareness of thoughts',
#   'awareness practice',
#   'balance',
#   'body scan',
#   'body-scan',
#   'breath',
#   'breathe',
#   'breathing',
#   'breathwork',
#   'calm',
#   'centered',
#   'centeredness',
#   'centering',
#   'clarity',
#   'compassion',
#   'compassion meditation',
#   'composure',
#   'concentration',
#   'connection',
#   'contemplation',
#   'deep listening',
#   'detachment',
#   'ease',
#   'embodied',
#   'empathy',
#   'equanimity',
#   'flow state',
#   'focus',
#   'gratitude',
#   'grounded',
#   'grounding',
#   'guided meditation',
#   'harmony',
#   'headspace',
#   'here and now',
#   'immersion',
#   'inner peace',
#   'inner-peace',
#   'insight',
#   'introspection',
#   'introspective',
#   'joy',
#   'kindness',
#   'letting go',
#   'liberation',
#   'loving-kindness',
#   'mantra',
#   'meditate',
#   'meditation',
#   'meditative',
#   'mindful',
#   'mindful breathing',
#   'mindful communication',
#   'mindful eating',
#   'mindful journaling',
#   'mindful movement',
#   'mindful walking',
#   'mindful-breathing',
#   'mindful-eating',
#   'mindful-listening',
#   'mindful-living',
#   'mindful-speaking',
#   'mindful-thinking',
#   'mindful-walking',
#   'mindfulness',
#   'mindfulness-based',
#   'nature connection',
#   'non-judgment',
#   'non-reactivity',
#   'nonattachment',
#   'nonjudgemental',
#   'nonreactive',
#   'notice',
#   'noticing',
#   'oneness',
#   'openness',
#   'pay attention',
#   'peace',
#   'peaceful',
#   'peacefulness',
#   'perception',
#   'presence',
#   'present moment',
#   'present-focused',
#   'reflection',
#   'reflective',
#   'relaxation',
#   'resilience',
#   'scanning',
#   'self-awareness',
#   'self-compassion',
#   'self-reflection',
#   'self-regulation',
#   'sensory',
#   'sensory experience',
#   'serenity',
#   'silence',
#   'soft',
#   'stillness',
#   'tranquility',
#   'understanding',
#   'unrolling',
#   'visualization',
#   'visualization techniques',
#   'yoga',
#   'zen',
#   'acceptance',
#   'acceptance and commitment',
#   'attention',
#   'attentiveness',
#   'attunement',
#   'awareness',
#   'awareness of breath',
#   'awareness of thought',
#   'awareness practice',
#   'balance',
#   'body scan',
#   'body - scan',
#   'breath',
#   'breathe',
#   'breathe',
#   'breathwork',
#   'calm',
#   'center',
#   'centeredness',
#   'center',
#   'clarity',
#   'compassion',
#   'compassion meditation',
#   'composure',
#   'concentration',
#   'connection',
#   'contemplation',
#   'deep listening',
#   'detachment',
#   'ease',
#   'embody',
#   'empathy',
#   'equanimity',
#   'flow state',
#   'focus',
#   'gratitude',
#   'ground',
#   'ground',
#   'guide meditation',
#   'harmony',
#   'headspace',
#   'here and now',
#   'immersion',
#   'inner peace',
#   'inner - peace',
#   'insight',
#   'introspection',
#   'introspective',
#   'joy',
#   'kindness',
#   'let go',
#   'liberation',
#   'love - kindness',
#   'mantra',
#   'meditate',
#   'meditation',
#   'meditative',
#   'mindful',
#   'mindful breathing',
#   'mindful communication',
#   'mindful eating',
#   'mindful journaling',
#   'mindful movement',
#   'mindful walking',
#   'mindful - breathing',
#   'mindful - eating',
#   'mindful - listen',
#   'mindful - living',
#   'mindful - speak',
#   'mindful - thinking',
#   'mindful - walk',
#   'mindfulness',
#   'mindfulness - base',
#   'nature connection',
#   'non - judgment',
#   'non - reactivity',
#   'nonattachment',
#   'nonjudgemental',
#   'nonreactive',
#   'notice',
#   'notice',
#   'oneness',
#   'openness',
#   'pay attention',
#   'peace',
#   'peaceful',
#   'peacefulness',
#   'perception',
#   'presence',
#   'present moment',
#   'present - focused',
#   'reflection',
#   'reflective',
#   'relaxation',
#   'resilience',
#   'scan',
#   'self - awareness',
#   'self - compassion',
#   'self - reflection',
#   'self - regulation',
#   'sensory',
#   'sensory experience',
#   'serenity',
#   'silence',
#   'soft',
#   'stillness',
#   'tranquility',
#   'understand',
#   'unroll',
#   'visualization',
#   'visualization technique',
#   'yoga',
#   'zen'],
#  'Compassion': ['acceptance',
#   'active listening',
#   'advocacy',
#   'affective empathy',
#   'altruism',
#   'attentiveness',
#   'attunement',
#   'benevolence',
#   'bonding',
#   'care',
#   'caregiving',
#   'caring',
#   'caring touch',
#   'charity',
#   'cognitive empathy',
#   'communality',
#   'community',
#   'compassion',
#   'compassion fatigue',
#   'compassion for all',
#   'compassion in action',
#   'compassion journey',
#   'compassion practice',
#   'compassion towards others',
#   'compassion towards self',
#   'compassionate response',
#   'compassionately',
#   'concern',
#   'connection',
#   'consideration',
#   'cooperative behavior',
#   'embrace',
#   'emotional contagion',
#   'emotional intelligence',
#   'emotional support',
#   'empathy',
#   'empathy fatigue',
#   'forgiveness',
#   'generosity',
#   'gentle touch',
#   'gentleness',
#   'goodwill',
#   'grace',
#   'gratitude',
#   'heartfelt',
#   'heartwarming',
#   'help others',
#   'hope',
#   'inclusion',
#   'kind',
#   'kindness',
#   'kindness meditation',
#   'listening',
#   'love',
#   'loving',
#   'loving-kindness',
#   'mental health',
#   'mercy',
#   'mindfulness',
#   'moral sensitivity',
#   'non-judgment',
#   'nonjudgmental',
#   'nurture',
#   'nurturing',
#   'open heart',
#   'outreach',
#   'presence',
#   'prosocial behavior',
#   'psychological safety',
#   'rapport',
#   'relational harmony',
#   'resilience',
#   'respect',
#   'self',
#   'selflessness',
#   'service',
#   'share',
#   'social connectedness',
#   'solace',
#   'solidarity',
#   'support',
#   'sympathy',
#   'tenderness',
#   'togetherness',
#   'tolerance',
#   'trust',
#   'unconditional positive regard',
#   'understanding',
#   'unity',
#   'uplift',
#   'uplifting',
#   'validation',
#   'vulnerability',
#   'warmth',
#   'well-being',
#   'acceptance',
#   'active listening',
#   'advocacy',
#   'affective empathy',
#   'altruism',
#   'attentiveness',
#   'attunement',
#   'benevolence',
#   'bond',
#   'care',
#   'caregive',
#   'care',
#   'care touch',
#   'charity',
#   'cognitive empathy',
#   'communality',
#   'community',
#   'compassion',
#   'compassion fatigue',
#   'compassion for all',
#   'compassion in action',
#   'compassion journey',
#   'compassion practice',
#   'compassion towards other',
#   'compassion towards self',
#   'compassionate response',
#   'compassionately',
#   'concern',
#   'connection',
#   'consideration',
#   'cooperative behavior',
#   'embrace',
#   'emotional contagion',
#   'emotional intelligence',
#   'emotional support',
#   'empathy',
#   'empathy fatigue',
#   'forgiveness',
#   'generosity',
#   'gentle touch',
#   'gentleness',
#   'goodwill',
#   'grace',
#   'gratitude',
#   'heartfelt',
#   'heartwarme',
#   'help other',
#   'hope',
#   'inclusion',
#   'kind',
#   'kindness',
#   'kindness meditation',
#   'listen',
#   'love',
#   'love',
#   'love - kindness',
#   'mental health',
#   'mercy',
#   'mindfulness',
#   'moral sensitivity',
#   'non - judgment',
#   'nonjudgmental',
#   'nurture',
#   'nurture',
#   'open heart',
#   'outreach',
#   'presence',
#   'prosocial behavior',
#   'psychological safety',
#   'rapport',
#   'relational harmony',
#   'resilience',
#   'respect',
#   'self',
#   'selflessness',
#   'service',
#   'share',
#   'social connectedness',
#   'solace',
#   'solidarity',
#   'support',
#   'sympathy',
#   'tenderness',
#   'togetherness',
#   'tolerance',
#   'trust',
#   'unconditional positive regard',
#   'understand',
#   'unity',
#   'uplift',
#   'uplift',
#   'validation',
#   'vulnerability',
#   'warmth',
#   'well - being']}

# %% [markdown]
# Or Load lexicon
# ```python
# path = './ct_lexicons/Insight/Insight_24-08-07T21-11-46.539980.pickle'
# my_lexicon = lexicon.load_lexicon(path)
# ```
#
# Or just create your own quickly with some keywords
# ```python
# lexicon_dict = {
#  	'Insight': 	['clarity', 'enlightenment', 'wise'],
#  	'Mindfulness': 	['mindful','meditation', 'awareness', 'nonjudgemental',
# 			'present-focused'],
#  	'Compassion': 	['compassion', 'love', 'kind', 'help others'],
#
#  }
#  ```

# %% [markdown]
# #### CTS step 2.2: Measure construct-text similarity

# %%
from construct_tracker import cts

features, documents_tokenized, lexicon_dict_final_order, cosine_similarities = cts.measure(
    lexicon_dict,
    documents,
	count_if_exact_match = 'sum',
	similarity_threshold = 0.3,
    )

display(features)

features.to_csv(f'{output_dir}insight_lexicon_cts_features.csv', index = False)
# Out:
# WARNING: stored_embeddings_path is None. Extracting all lexicon token embeddings from scratch instead of loading stored embeddings...
# INFO: Default input sequence length for all-MiniLM-L6-v2: 256
# INFO: Encoding 568 new construct tokens...
# Batches:   0%|          | 0/18 [00:00<?, ?it/s]
# INFO: Finished encoding construct tokens.
# INFO: Tokenizing documents...
# INFO: Finished tokenization.
# INFO: Encoding all document tokens...
# INFO: computing similarity between 3 constructs and 3 documents...
# 3it [00:00, 194.78it/s]
# INFO: Finished.
# INFO: Adding 'Insight' to the lexicon (it was not previously there). If you meant to add to an existing construct (and have a typo in the construct name, which is case sensitive), run: del your_lexicon_name.constructs['Insight']
# INFO: Adding 'Mindfulness' to the lexicon (it was not previously there). If you meant to add to an existing construct (and have a typo in the construct name, which is case sensitive), run: del your_lexicon_name.constructs['Mindfulness']
# INFO: Adding 'Compassion' to the lexicon (it was not previously there). If you meant to add to an existing construct (and have a typo in the construct name, which is case sensitive), run: del your_lexicon_name.constructs['Compassion']
# extracting...
#   0%|          | 0/3 [00:00<?, ?it/s]WARNING: Lemmatizing the tokens. We recommend you lemmatize before extracting so you can save time if you want to repeat extraction on different documents.
#  33%|███▎      | 1/3 [00:00<00:01,  1.61it/s]WARNING: Lemmatizing the tokens. We recommend you lemmatize before extracting so you can save time if you want to repeat extraction on different documents.
#  67%|██████▋   | 2/3 [00:01<00:00,  1.34it/s]WARNING: Lemmatizing the tokens. We recommend you lemmatize before extracting so you can save time if you want to repeat extraction on different documents.
# 100%|██████████| 3/3 [00:02<00:00,  1.44it/s]
#    document_id                                          documents  \
# 0            1  Every time I speak with my cousin Bob, I have ...
# 1            2       He meditates a lot, but he's not super smart
# 2            0                              He is too competitive
#
#                                  documents_tokenized  Insight_max  \
# 0  [Every time I speak with my cousin Bob, I have...     3.482038
# 1         [He meditates a lot, he's not super smart]     0.000000
# 2                            [He is too competitive]     0.447937
#
#    Mindfulness_max  Compassion_max
# 0         2.715475        0.482038
# 1         1.000000        0.000000
# 2         0.382691        0.327205

# %% [markdown]
# You can also provide a counts DF done in a different way:
#
# ```python
# counts, matches_by_construct, matches_doc2construct, matches_construct2doc  = my_lexicon.extract(documents,normalize = True,return_zero=['anger'])
#
# from construct_tracker import cts
#
# features, documents_tokenized, lexicon_dict_final_order, cosine_similarities = cts.measure(
#     lexicon_dict,
#     documents,
# 	lexicon_counts = counts,
# 	count_if_exact_match = 'sum',
# 	similarity_threshold = 0.3,
#     )
#
# display(features)
# ```

# %% [markdown]
# #### CTS step 2.3: Interpret cosine scores for any given document

# %%
doc_id = 2
construct = 'Mindfulness'
most_similar_lexicon_token, most_similar_document_token, highest_similarity = cts.get_highest_similarity_phrase(doc_id, construct, documents, documents_tokenized, cosine_similarities, lexicon_dict_final_order)
# Out:
# The construct 'Mindfulness' through its token 'oneness' had the highest cosine similarity (0.24) with the following document token:
# 'He is too competitive'
# <mark>He is too competitive</mark>
